# %% [markdown]
# <a href="https://colab.research.google.com/github/FadliUjangJoget/Pemrograman-Dasar/blob/main/ATS_pemorgraman_Dasar_Kelompok_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# No. 2

# %%
# Fungsi untuk menghitung efisiensi turbin
def hitung_efisiensi(input_energi, output_energi):
    # b. Mengembalikan nilai efisiensi
    efisiensi = output_energi / input_energi
    return efisiensi

# c. Contoh pemanggilan fungsi
hasil = hitung_efisiensi(500, 400)

# Menampilkan hasil efisiensi
print("Efisiensi turbin =", hasil * 100, "%")
# Out:
# Efisiensi turbin = 80.0 %

# %% [markdown]
# Penjelasan
#
# Program pada gambar tersebut digunakan untuk menghitung efisiensi turbin dengan menggunakan fungsi dalam Python. Fungsi bernama hitung_efisiensi memiliki dua parameter, yaitu input_energi sebagai energi masuk dan output_energi sebagai energi keluar dari turbin. Di dalam fungsi, efisiensi dihitung menggunakan rumus efisiensi = output_energi / input_energi, kemudian hasil perhitungan tersebut dikembalikan dengan perintah return. Setelah itu, fungsi dipanggil dengan nilai masukan input_energi = 500 dan output_energi = 400, sehingga diperoleh nilai efisiensi sebesar 0.8. Nilai ini kemudian dikalikan dengan 100 agar hasilnya dalam bentuk persen, dan ditampilkan menggunakan perintah print. Hasil akhirnya menunjukkan bahwa efisiensi turbin adalah 80,0%, yang berarti turbin mampu mengubah 80% energi masuk menjadi energi keluaran yang berguna.

# %% [markdown]
# No. 4

# %%
# Input data
tekanan_uap = float(input("Masukkan tekanan uap (psi): "))
status_manual_override = False  # contoh status manual override

# Logika if majemuk
if tekanan_uap > 150 and status_manual_override == False:
    print("Katup Terbuka")
else:
    print("Katup Tetap Tertutup")
# Out:
# Masukkan tekanan uap (psi): 170
# Katup Terbuka

# %% [markdown]
# Penjelasan
#
# Program pada gambar tersebut berfungsi untuk menentukan kondisi katup (valve) berdasarkan tekanan uap dan status manual override. Pertama, program meminta pengguna memasukkan nilai tekanan uap dalam satuan psi melalui perintah input(), kemudian nilai tersebut diubah menjadi tipe data float agar bisa digunakan dalam perbandingan numerik. Variabel status_manual_override diatur bernilai False sebagai contoh, yang berarti sistem manual override tidak diaktifkan.
#
# Selanjutnya, digunakan logika if majemuk dengan kondisi if tekanan_uap > 150 and status_manual_override == False:. Artinya, katup akan terbuka hanya jika tekanan uap lebih besar dari 150 psi dan manual override tidak aktif. Jika kedua syarat tersebut terpenuhi, program menampilkan pesan “Katup Terbuka”. Sebaliknya, jika salah satu kondisi tidak terpenuhi, maka program menampilkan “Katup Tetap Tertutup”.

# %% [markdown]
# No. 6

# %%
# Program menghitung daya listrik (P = V × I)

# Diketahui:
tegangan = 220  # Volt
arus = 15       # Ampere

# Rumus daya listrik
daya = tegangan * arus

# Menampilkan hasil
print("Daya listrik yang dihasilkan =", daya, "Watt")
# Out:
# Daya listrik yang dihasilkan = 3300 Watt

# %% [markdown]
# Penjelasan
#
# Program pada gambar tersebut digunakan untuk menghitung daya listrik dengan menggunakan rumus dasar listrik yaitu
# 𝑃=
# 𝑉
# ×
# 𝐼
# di mana P adalah daya (watt), V adalah tegangan (volt), dan I adalah arus (ampere).
#
# program mendefinisikan nilai tegangan sebesar 220 volt dan arus sebesar 15 ampere. Kedua nilai ini kemudian digunakan dalam perhitungan daya dengan rumus daya = tegangan * arus. Hasil perkalian tersebut menghasilkan nilai daya listrik sebesar 3300 watt.

# %% [markdown]
# No. 8

# %%
# Fungsi untuk menghitung efisiensi termal turbin gas
def hitung_efisiensi_termal(energi_masuk, energi_keluar):
    efisiensi = (energi_keluar / energi_masuk) * 100
    print("Efisiensi termal turbin gas =", efisiensi, "%")

# Contoh pemanggilan fungsi
hitung_efisiensi_termal(500, 400)
# Out:
# Efisiensi termal turbin gas = 80.0 %

# %% [markdown]
# Penjelasan
#
# Program pada gambar tersebut digunakan untuk menghitung efisiensi termal turbin gas dengan menggunakan fungsi dalam Python. Fungsi yang dibuat bernama hitung_efisiensi_termal, dan memiliki dua parameter yaitu energi_masuk serta energi_keluar
# Setelah perhitungan dilakukan, hasil efisiensi ditampilkan menggunakan perintah print("Efisiensi termal turbin gas =", efisiensi, "%"). Pada bagian pemanggilan fungsi, digunakan nilai energi_masuk = 500 dan energi_keluar = 400
# Sehingga program menampilkan output “Efisiensi termal turbin gas = 80.0 %”, yang berarti turbin gas bekerja dengan efisiensi sebesar 80 persen dari energi panas yang diterimanya.

# %% [markdown]
# No. 10

# %%
# Inisialisasi volume awal tangki
tangki = 0

# Loop pengisian bahan bakar
while tangki < 100:
    tangki += 10  # Naikkan 10 liter setiap iterasi
    print("Volume saat ini:", tangki, "liter")

    # Peringatan saat hampir penuh
    if tangki == 80:
        print("WARNING: Hampir penuh!")

    # Pesan saat tangki penuh
    if tangki == 100:
        print("TANGKI PENUH – Pengisian berhenti.")
# Out:
# Volume saat ini: 10 liter
# Volume saat ini: 20 liter
# Volume saat ini: 30 liter
# Volume saat ini: 40 liter
# Volume saat ini: 50 liter
# Volume saat ini: 60 liter
# Volume saat ini: 70 liter
# Volume saat ini: 80 liter
# WARNING: Hampir penuh!
# Volume saat ini: 90 liter
# Volume saat ini: 100 liter
# TANGKI PENUH – Pengisian berhenti.

# %% [markdown]
# Penjelasan
#
# Program pada gambar tersebut digunakan untuk mensimulasikan proses pengisian tangki bahan bakar hingga penuh dengan menambahkan volume secara bertahap.
#
# Pertama, variabel tangki diinisialisasi dengan nilai 0, yang berarti tangki dalam keadaan kosong. Kemudian digunakan perulangan while tangki < 100, artinya program akan terus berjalan selama volume tangki masih kurang dari 100 liter. Di dalam loop, setiap iterasi menambah volume tangki sebesar 10 liter menggunakan tangki += 10, lalu menampilkan volume saat ini dengan perintah print("Volume saat ini:", tangki, "liter").

# %% [markdown]
# Challenge

# %%
# ==========================================
# PROGRAM MONITORING DAYA & EFISIENSI GENERATOR
# ==========================================

# Fungsi untuk menghitung daya listrik (P = V × I)
def hitung_daya(tegangan, arus):
    return tegangan * arus

# Fungsi untuk menghitung efisiensi generator (%)
def hitung_efisiensi(energi_masuk, energi_keluar):
    return (energi_keluar / energi_masuk) * 100

# Fungsi utama (main program)
def main():
    print("=== SISTEM MONITORING ENERGI GENERATOR ===\n")

    # Perulangan while untuk membaca beberapa unit generator
    unit = 1
    while unit <= 3:  # misalnya ada 3 generator
        print(f"\n--- Generator {unit} ---")

        # Input data
        tegangan = float(input("Masukkan tegangan (Volt): "))
        arus = float(input("Masukkan arus (Ampere): "))
        energi_masuk = float(input("Masukkan energi masuk (kJ): "))
        energi_keluar = float(input("Masukkan energi keluar (kJ): "))

        # Hitung daya dan efisiensi menggunakan fungsi
        daya = hitung_daya(tegangan, arus)
        efisiensi = hitung_efisiensi(energi_masuk, energi_keluar)

        # Tampilkan hasil
        print(f"\nDaya listrik: {daya} Watt")
        print(f"Efisiensi: {efisiensi:.2f}%")

        # Percabangan if-elif-else untuk menilai kondisi generator
        if efisiensi >= 90:
            print("STATUS: Generator sangat efisien ✅")
        elif efisiensi >= 75:
            print("STATUS: Generator efisien ⚙️")
        elif efisiensi >= 60:
            print("STATUS: Generator kurang efisien ⚠️")
        else:
            print("STATUS: Generator tidak efisien ❌")

        unit += 1  # lanjut ke unit berikutnya

    # Setelah semua generator dihitung, tampilkan ringkasan
    print("\n=== PEMERIKSAAN SUHU OPERASI ===")
    suhu_operasi = [85, 92, 97, 105, 89]  # contoh data suhu
    for i in range(len(suhu_operasi)):
        print(f"Unit {i+1}: {suhu_operasi[i]}°C", end="  ")
        if suhu_operasi[i] > 100:
            print("⚠️ WARNING: Suhu berlebih!")
        else:
            print("✅ Suhu normal.")

    print("\n=== PENGISIAN TANGKI BAHAN BAKAR ===")
    volume = 0
    while volume < 100:
        volume += 20
        print(f"Tangki terisi {volume} liter")
        if volume == 80:
            print("WARNING: Hampir penuh!")
        elif volume >= 100:
            print("TANGKI PENUH – Pengisian berhenti.")
            break

# Jalankan program utama
main()
# Out:
# === SISTEM MONITORING ENERGI GENERATOR ===
#
#
# --- Generator 1 ---
# Masukkan tegangan (Volt): 220
# Masukkan arus (Ampere): 10
# Masukkan energi masuk (kJ): 500
# Masukkan energi keluar (kJ): 400
#
# Daya listrik: 2200.0 Watt
# Efisiensi: 80.00%
# STATUS: Generator efisien ⚙️
#
# --- Generator 2 ---
# Masukkan tegangan (Volt): 389
# Masukkan arus (Ampere): 35
# Masukkan energi masuk (kJ): 500
# Masukkan energi keluar (kJ): 400
#
# Daya listrik: 13615.0 Watt
# Efisiensi: 80.00%
# STATUS: Generator efisien ⚙️
#
# --- Generator 3 ---
# Masukkan tegangan (Volt): 380
# Masukkan arus (Ampere): 20
# Masukkan energi masuk (kJ): 250
# Masukkan energi keluar (kJ): 200
#
# Daya listrik: 7600.0 Watt
# Efisiensi: 80.00%
# STATUS: Generator efisien ⚙️
#
# === PEMERIKSAAN SUHU OPERASI ===
# Unit 1: 85°C  ✅ Suhu normal.
# Unit 2: 92°C  ✅ Suhu normal.
# Unit 3: 97°C  ✅ Suhu normal.
# Unit 4: 105°C  ⚠️ WARNING: Suhu berlebih!
# Unit 5: 89°C  ✅ Suhu normal.
#
# === PENGISIAN TANGKI BAHAN BAKAR ===
# ...
